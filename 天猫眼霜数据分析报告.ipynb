# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import re
import json
import glob
from bs4 import BeautifulSoup as bs
from functools import reduce
pd.options.display.max_columns = 50

import matplotlib.pyplot as plt
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

import pyecharts
from pyecharts import options as opts

import jieba
from jieba import analyse
stop_words_path = r"C:\\Users\\root\\Desktop\\tmall_crawler\\stopwords-master\\中文停用词表.txt"
analyse.set_stop_words(stop_words_path)
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

# %% [markdown]
# # 天猫眼霜分析报告

# %% [markdown]
# ## 1. 数据处理

# %% [markdown]
# ### 1.1 HTML文本解析和内容抽取

# %%
# 数据预处理函数

# 解析html文件函数
def parser(file):
    with open(file, 'r', encoding='utf-8') as f:
        html = f.read()
    html = bs(html, 'lxml').text
    try:
        if html.startswith('{'):
            item = json.loads(html)
            return ('json', item)
        else:
            item = re.search(r'g_page_config = ({.*?});', html).group(1)
            item = json.loads(item)
            return ('html', item)
    except Exception as e:
        print(file)
        return None
    
# 清晰json内部数据
# 其中一条来自纯json数据，字段与正常html字段相差太多，强行整合效果和效益不高，故弃之；后期改进
def clean_content(content):
    def filter_keys(x):
        data = {}
        for key in keys:
            data[key] = x[key]
        return data
    
    if content[0] == 'html':
        data = content[1]['mods']['itemlist']['data']['auctions']
        intersection_keys = reduce(lambda x,y: x.intersection(y), [set(item.keys()) for item in data])
        keys = intersection_keys
        data = [filter_keys(x) for x in data]
        return data
    else:
        return None
    
# 操作整合， 最终数据调用函数
def getData(files='./data/item*'):
    files = glob.glob(files)
    df = pd.DataFrame({'file':files})
    df['content'] = df.file.map(parser).map(clean_content)
    df = df[pd.notna(df.content)]
    data = reduce(lambda x,y: x+y ,df.content.tolist())
    df = pd.DataFrame(data)
    return df

# %% [markdown]
# ### 1.2 字段抽取和数据加工

# %%
def clean_data(df):
    # 剔除字段
    drop_columns = ['comment_url', 'icon', 'pic_url', 'shopLink', 'view_fee', 'title', 'shopcard', 'i2iTags', 'p4pTags', 'risk', 'pid']
    df = df.drop(columns=drop_columns)
    df.head()
    ## 提出重复着，经验证，nid是商品id，根据nid去重
    df = df.drop_duplicates(subset=['nid'], keep='first')
    # 查看view_sales缺失情况，根据情况决定是否删除还是按0填补
    # df.view_sales.map(pd.notna).value_counts()
    # 直接剔除view_sales空的商品
    # df[df.category.map(len)<2]
    # 分类category字段只有一条为空的数据，直接剔除
    df =df.dropna(axis=0, subset=['view_sales','category'], how='any')
    def lint(x):
        try: return int(x)
        except: return 0
    def lfloat(x):
        try: return float(x)
        except: return 0.
    # 字段清洗
    df.view_sales = df.view_sales.map(lambda x: re.match(r'([0-9]+)', x).group(1)).map(lint)
    df.comment_count = df.comment_count.map(lint)
    df.view_price = df.view_price.map(lfloat)
    df.item_loc = df.item_loc.map(lambda x: x.split(' ')[0])
#     是否是丸美店铺
    df['is_marubi_shop'] = df.nick.map(lambda x: '丸美' in x)
#     是否是丸美商品
    df['is_marubi_item'] = df.raw_title.map(lambda x: '丸美' in x)
#     标题分词
    df['raw_title_cut'] = df.raw_title.map(jieba.cut).map(list)
    return df

# %%
df =getData()
df = clean_data(df)

# %%
df.head()
# Out:
#      category           nid  comment_count           nick  view_price  \
# 48  121484013  599083945560             17       天猫国际进口超市       615.0
# 49  121484013  599326258570           1370  newface新面孔旗舰店        76.0
# 50  121484013  549317594016            381       珀莱雅铭博专卖店       196.0
# 51  121484013  593792520101           1159        大宝官方旗舰店       129.0
# 52  121484013  586188427656            317         温碧泉旗舰店       313.0
#
#                             raw_title     user_id item_loc  \
# 48  MedSPA/美帕瑞士蛇毒无痕修复眼霜提拉紧致抗皱淡化细纹去脂肪粒  2549841410       浙江
# 49      新面孔日夜金眼霜黑眼圈眼袋干细纹抗皱补水正品女三合一脂肪粒  2250956384       浙江
# 50     珀莱雅弹润芯肌活力眼霜去补水细纹紧致抗皱抗衰老官方旗舰店官网  2778000028       浙江
# 51             大宝眼霜女提拉紧致小红帽眼部精华按摩眼部护理   500327991       上海
# 52     温碧泉初生精华眼霜抗初老提拉紧致抗皱去黑眼圈祛眼袋淡化细纹女   661544293       广东
#
#                                            detail_url  view_sales  \
# 48  //detail.tmall.com/item.htm?id=599083945560&ns...           2
# 49  //detail.tmall.com/item.htm?id=599326258570&ns...         583
# 50  //detail.tmall.com/item.htm?id=549317594016&ns...          50
# 51  //detail.tmall.com/item.htm?id=593792520101&ns...          18
# 52  //detail.tmall.com/item.htm?id=586188427656&ns...          19
#
#     is_marubi_shop  is_marubi_item  \
# 48           False           False
# 49           False           False
# 50           False           False
# 51           False           False
# 52           False           False
#
#                                         raw_title_cut
# 48  [MedSPA, /, 美帕, 瑞士, 蛇毒, 无痕, 修复, 眼霜, 提拉, 紧致, 抗皱...
# 49  [新面孔, 日夜, 金, 眼霜, 黑眼圈, 眼袋, 干, 细纹, 抗皱, 补水, 正品, 女...
# 50  [珀莱雅, 弹润, 芯, 肌, 活力, 眼霜, 去, 补水, 细纹, 紧致, 抗皱, 抗衰老...
# 51       [大宝, 眼霜, 女, 提拉, 紧致, 小红帽, 眼部, 精华, 按摩, 眼部, 护理]
# 52  [温碧泉, 初生, 精华, 眼霜, 抗初, 老, 提拉, 紧致, 抗皱, 去, 黑眼圈, 祛...

# %% [markdown]
# ## 2.数据分析专题

# %% [markdown]
# ### 2.1 市场分析

# %%
data1 = df.nick.value_counts(dropna=False).reset_index(name='item_count').sort_values('item_count',ascending=False)
bar1 = (
    pyecharts.charts.Bar()
    .add_xaxis(data1['index'].head(10).tolist())
    .add_yaxis('SKU数量', data1.head(10).item_count.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='眼霜市场 - 商品数量TOP10店铺'))
)
bar1.load_javascript()

# %%
bar1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="f9a4294cb55c4d629cb663b35b238086" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_f9a4294cb55c4d629cb663b35b238086 = echarts.init(
#             document.getElementById('f9a4294cb55c4d629cb663b35b238086'), 'white', {renderer: 'canvas'});
#         var option_f9a4294cb55c4d629cb663b35b238086 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "SKU\u6570\u91cf",
#             "data": [
#                 66,
#                 48,
#                 31,
#                 28,
#                 26,
#                 22,
#                 20,
#                 19,
#                 17,
#                 16
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "SKU\u6570\u91cf"
#             ],
#             "selected": {
#                 "SKU\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5929\u732b\u56fd\u9645\u6d77\u5916\u4ed3\u76f4\u8d2d",
#                 "\u5929\u732b\u56fd\u9645\u8fdb\u53e3\u8d85\u5e02",
#                 "\u5929\u732b\u8d85\u5e02",
#                 "\u5929\u732b\u56fd\u9645\u5999\u989c\u793e",
#                 "chemistwarehouse\u6d77\u5916\u65d7\u8230",
#                 "\u4e38\u7f8e\u65d7\u8230\u5e97",
#                 "\u5c48\u81e3\u6c0f\u5b98\u65b9\u65d7\u8230\u5e97",
#                 "\u4e38\u7f8e\u91d1\u672a\u6765\u4e13\u5356\u5e97",
#                 "\u9a6c\u5e94\u9f99\u5927\u836f\u623f\u65d7\u8230\u5e97",
#                 "\u4e38\u7f8e\u5a07\u989c\u4e13\u5356\u5e97"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u773c\u971c\u5e02\u573a - \u5546\u54c1\u6570\u91cfTOP10\u5e97\u94fa"
#         }
#     ]
# };
#         chart_f9a4294cb55c4d629cb663b35b238086.setOption(option_f9a4294cb55c4d629cb663b35b238086);
#     </script>
# </body>
# </html>

# %%
data2 = df[['view_sales', 'nick']].groupby(['nick']).sum().sort_values('view_sales', ascending=False)
bar2 = (
    pyecharts.charts.Bar()
    .add_xaxis(data2.head(10).index.tolist())
    .add_yaxis('眼霜销量', data2.head(10).view_sales.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='眼霜市场 - 商品销量TOP10店铺'))
)
bar2.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6a1de0a604b8477b884df305595d4fee" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_6a1de0a604b8477b884df305595d4fee = echarts.init(
#             document.getElementById('6a1de0a604b8477b884df305595d4fee'), 'white', {renderer: 'canvas'});
#         var option_6a1de0a604b8477b884df305595d4fee = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 31,
#                 52,
#                 176,
#                 56,
#                 79,
#                 102,
#                 120,
#                 122,
#                 158,
#                 189
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5546\u54c1\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u529f\u80fd",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u773c\u90e8",
#                 "\u63d0\u62c9",
#                 "\u6b63\u54c1",
#                 "\u4fdd\u6e7f",
#                 "\u8865\u6c34",
#                 "\u773c\u888b",
#                 "\u9ed1\u773c\u5708",
#                 "\u6de1\u5316",
#                 "\u7ec6\u7eb9",
#                 "\u773c\u971c"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e38\u7f8e\u773c\u971c - \u529f\u80fd\u4e0e\u5546\u54c1\u6570\u91cf TOP10"
#         }
#     ]
# };
#         chart_6a1de0a604b8477b884df305595d4fee.setOption(option_6a1de0a604b8477b884df305595d4fee);
#     </script>
# </body>
# </html>

# %%
data3 =df[df.is_marubi_shop].nick.value_counts(dropna=False).reset_index(name='item_count').sort_values('item_count',ascending=False)
bar3 = (
    pyecharts.charts.Bar()
    .add_xaxis(data3['index'].head(10).tolist())
    .add_yaxis('丸美专卖店SKU数量', data3.head(10).item_count.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='丸美眼霜 - 商品数量TOP10店铺'))
)
bar3.load_javascript()

# %%
bar3.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ee73e0f574244c5eb8de180f5c00ac9b" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_ee73e0f574244c5eb8de180f5c00ac9b = echarts.init(
#             document.getElementById('ee73e0f574244c5eb8de180f5c00ac9b'), 'white', {renderer: 'canvas'});
#         var option_ee73e0f574244c5eb8de180f5c00ac9b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e38\u7f8e\u4e13\u5356\u5e97SKU\u6570\u91cf",
#             "data": [
#                 22,
#                 19,
#                 16,
#                 16,
#                 14,
#                 14,
#                 13,
#                 12
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e38\u7f8e\u4e13\u5356\u5e97SKU\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u4e38\u7f8e\u4e13\u5356\u5e97SKU\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e38\u7f8e\u65d7\u8230\u5e97",
#                 "\u4e38\u7f8e\u91d1\u672a\u6765\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u5c1a\u65f6\u7f8e\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u5a07\u989c\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u540d\u8f69\u4e13\u5356\u5e97",
#                 "marubi\u4e38\u7f8e\u7ea2\u52a8\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u946b\u4e1d\u8def\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u4e03\u67ef\u4e13\u5356\u5e97"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e38\u7f8e\u773c\u971c - \u5546\u54c1\u6570\u91cfTOP10\u5e97\u94fa"
#         }
#     ]
# };
#         chart_ee73e0f574244c5eb8de180f5c00ac9b.setOption(option_ee73e0f574244c5eb8de180f5c00ac9b);
#     </script>
# </body>
# </html>

# %%
data4 = df[df.is_marubi_item][['view_sales', 'nick']].groupby(['nick']).sum().sort_values('view_sales', ascending=False)
bar4 = (
    pyecharts.charts.Bar()
    .add_xaxis(data4.head(10).index.tolist())
    .add_yaxis('丸美眼霜销量', data4.head(10).view_sales.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='丸美眼霜 - 商品销量TOP10店铺'))
)
bar4.load_javascript()

# %%
bar4.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="61d933b1f4fa442fa0965780f751edd8" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_61d933b1f4fa442fa0965780f751edd8 = echarts.init(
#             document.getElementById('61d933b1f4fa442fa0965780f751edd8'), 'white', {renderer: 'canvas'});
#         var option_61d933b1f4fa442fa0965780f751edd8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e38\u7f8e\u773c\u971c\u9500\u91cf",
#             "data": [
#                 16524,
#                 10715,
#                 5356,
#                 4865,
#                 3243,
#                 3131,
#                 1985,
#                 1717,
#                 1480,
#                 1326
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e38\u7f8e\u773c\u971c\u9500\u91cf"
#             ],
#             "selected": {
#                 "\u4e38\u7f8e\u773c\u971c\u9500\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e38\u7f8e\u65d7\u8230\u5e97",
#                 "\u4e38\u7f8e\u5a07\u989c\u4e13\u5356\u5e97",
#                 "\u5929\u732b\u8d85\u5e02",
#                 "\u4e38\u7f8e\u540d\u8f69\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u91d1\u672a\u6765\u4e13\u5356\u5e97",
#                 "marubi\u4e38\u7f8e\u7ea2\u52a8\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u5c1a\u65f6\u7f8e\u4e13\u5356\u5e97",
#                 "\u5c0f\u679c\u5316\u5986\u54c1\u4e13\u8425\u5e97",
#                 "\u4e38\u7f8e\u4e03\u67ef\u4e13\u5356\u5e97",
#                 "\u4e38\u7f8e\u946b\u4e1d\u8def\u4e13\u5356\u5e97"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e38\u7f8e\u773c\u971c - \u5546\u54c1\u9500\u91cfTOP10\u5e97\u94fa"
#         }
#     ]
# };
#         chart_61d933b1f4fa442fa0965780f751edd8.setOption(option_61d933b1f4fa442fa0965780f751edd8);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### 结论分析一
#
# #### 整体市场
#
# 1. 除去天猫超市，天猫国际等综合品牌店铺，各个品牌的眼霜SKU相差不大。
# 2. 从销量上看，各类品牌的销量差距较大，天猫超市、玖美堂旗舰店、丸美位列销量前三，并且远高于其他品牌旗舰店
#
# #### 丸美眼霜
#
# 1. 丸美各个专卖店的SKU差距不大，评价在16个SKU左右；
# 2. 丸美眼霜的大部分销量都来自丸美旗舰店和丸美娇颜专卖店；
# 3. 丸美旗舰店的旗舰标识和较多的SKU使其成为丸美眼霜销售的核心店铺，对推广整个丸美眼霜产品有重要的影响力；
# 4. 丸美娇颜专门店虽然SKU较少，但销量位列第二，可以重点关注在丸美娇颜专门打造爆款。

# %% [markdown]
# ### 2.2 卖点分析

# %%
keywords_count_list_all = jieba.analyse.textrank(' '.join(df.raw_title.tolist()), topK=50, withWeight=True)
word_cloud1 = (
    WordCloud()
    .add("", keywords_count_list_all, word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title='眼霜市场 - 功能卖点TOP20'))
)
word_cloud1.load_javascript()

# %%
word_cloud1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1596354e2b92430a89cb9fe4c4f9d810" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1596354e2b92430a89cb9fe4c4f9d810 = echarts.init(
#             document.getElementById('1596354e2b92430a89cb9fe4c4f9d810'), 'white', {renderer: 'canvas'});
#         var option_1596354e2b92430a89cb9fe4c4f9d810 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u773c\u971c",
#                     "value": 1.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,127,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ec6\u7eb9",
#                     "value": 0.6417814568339522,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,65,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6de1\u5316",
#                     "value": 0.6166737165708622,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,7,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ed1\u773c\u5708",
#                     "value": 0.5877546245125562,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,17,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u773c\u888b",
#                     "value": 0.43877319526927633,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,69,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8865\u6c34",
#                     "value": 0.41793811569933637,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,49,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fdd\u6e7f",
#                     "value": 0.4108358152338739,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,36,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b63\u54c1",
#                     "value": 0.27302269627813763,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,70,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u63d0\u62c9",
#                     "value": 0.24154188195926865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,5,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u773c\u90e8",
#                     "value": 0.24133997397455517,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,128,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65d7\u8230\u5e97",
#                     "value": 0.15640115323869055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,98,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fee\u62a4",
#                     "value": 0.11118229778190333,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,143,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ecb\u6da6",
#                     "value": 0.10829800836879785,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,127,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b66\u751f",
#                     "value": 0.09089317972266057,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,136,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6539\u5584",
#                     "value": 0.08987092966336667,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,7,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b98\u65b9",
#                     "value": 0.08866886057274566,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,20,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b98\u7f51",
#                     "value": 0.08607537308114233,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,58,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8102\u80aa\u7c92",
#                     "value": 0.06037993309764853,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,103,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u67dc",
#                     "value": 0.04775115592906212,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,71,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e72\u7eb9",
#                     "value": 0.04570498927673802,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,29,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ecb\u517b",
#                     "value": 0.04518631859582107,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,21,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u773c\u7eb9",
#                     "value": 0.04479216756609171,

# %%
keywords_count_list_marubi = jieba.analyse.textrank(' '.join(df[df.is_marubi_item].raw_title.tolist()), topK=50, withWeight=True)
word_cloud2 = (
    WordCloud()
    .add("", keywords_count_list_marubi, word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title='丸美眼霜 - 功能卖点TOP20'))
)
word_cloud2.load_javascript()

# %%
word_cloud2.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6b18c50eb6514e68afd1dacdd1007a86" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_6b18c50eb6514e68afd1dacdd1007a86 = echarts.init(
#             document.getElementById('6b18c50eb6514e68afd1dacdd1007a86'), 'white', {renderer: 'canvas'});
#         var option_6b18c50eb6514e68afd1dacdd1007a86 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u7ec6\u7eb9",
#                     "value": 1.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,28,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u773c\u971c",
#                     "value": 0.9763213734438391,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,25,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6de1\u5316",
#                     "value": 0.8620691800542712,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,143,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b63\u54c1",
#                     "value": 0.8484985988584112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,101,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65d7\u8230\u5e97",
#                     "value": 0.8481149009085639,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,102,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ed1\u773c\u5708",
#                     "value": 0.8158365326754204,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,112,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b98\u7f51",
#                     "value": 0.7214987612325939,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,24,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u773c\u888b",
#                     "value": 0.6584395259630479,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,32,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8865\u6c34",
#                     "value": 0.5800673826423696,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,71,55)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fdd\u6e7f",
#                     "value": 0.41660491900869184,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,73,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u63d0\u62c9",
#                     "value": 0.33472097691671726,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,145,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u773c\u90e8",
#                     "value": 0.19492338908642845,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,137,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u86cb\u767d",
#                     "value": 0.1795173414855301,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,68,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f39\u529b",
#                     "value": 0.1510176223484213,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,68,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5957\u88c5",
#                     "value": 0.12965247034547092,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,149,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51dd\u80f6",
#                     "value": 0.11316576035944889,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,140,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fee\u62a4",
#                     "value": 0.10440956929285446,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,24,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u67dc",
#                     "value": 0.09711869582682955,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,31,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u534e\u7d20",
#                     "value": 0.0942431543612051,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,54,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ecb\u6da6",
#                     "value": 0.09286749679404661,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,116,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b66\u751f",
#                     "value": 0.08860905463690641,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,48,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f39\u5f39",
#                     "value": 0.08559012644744715,

# %%
def filter_keyword_sales(df, keyword):
    return int(df[df.raw_title_cut.map(lambda x: keyword in x)]['view_sales'].mean())

# %%
keywords_mean_sales_all = {i[0]:filter_keyword_sales(df,i[0]) for i in reversed(keywords_count_list_all[:10])}
bar = (
    pyecharts.charts.Bar()
    .add_xaxis(list(keywords_mean_sales_all.keys()))
    .add_yaxis("", list(keywords_mean_sales_all.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position='right'))
    .set_global_opts(
        title_opts = opts.TitleOpts(title="眼霜市场 - 功能卖点与平均销量TOP10"),
        yaxis_opts = opts.AxisOpts(name='功能'),
        xaxis_opts = opts.AxisOpts(name='平均销量')
    )
)
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="35d5cf26aeec471ab3b1d36ef860841f" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_35d5cf26aeec471ab3b1d36ef860841f = echarts.init(
#             document.getElementById('35d5cf26aeec471ab3b1d36ef860841f'), 'white', {renderer: 'canvas'});
#         var option_35d5cf26aeec471ab3b1d36ef860841f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 110,
#                 142,
#                 128,
#                 138,
#                 150,
#                 159,
#                 151,
#                 145,
#                 140,
#                 124
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u529f\u80fd",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u773c\u90e8",
#                 "\u63d0\u62c9",
#                 "\u6b63\u54c1",
#                 "\u4fdd\u6e7f",
#                 "\u8865\u6c34",
#                 "\u773c\u888b",
#                 "\u9ed1\u773c\u5708",
#                 "\u6de1\u5316",
#                 "\u7ec6\u7eb9",
#                 "\u773c\u971c"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u773c\u971c\u5e02\u573a - \u529f\u80fd\u5356\u70b9\u4e0e\u5e73\u5747\u9500\u91cfTOP10"
#         }
#     ]
# };
#         chart_35d5cf26aeec471ab3b1d36ef860841f.setOption(option_35d5cf26aeec471ab3b1d36ef860841f);
#     </script>
# </body>
# </html>

# %%
keywords_mean_sales_marubi = {i[0]:filter_keyword_sales(df[df.is_marubi_item],i[0]) for i in reversed(keywords_count_list_all[:10])}
bar = (
    pyecharts.charts.Bar()
    .add_xaxis(list(keywords_mean_sales_marubi.keys()))
    .add_yaxis("", list(keywords_mean_sales_marubi.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position='right'))
    .set_global_opts(
        title_opts = opts.TitleOpts(title="丸美眼霜 - 功能卖点与平均销量TOP10"),
        yaxis_opts = opts.AxisOpts(name='功能'),
        xaxis_opts = opts.AxisOpts(name='平均销量')
    )
)
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="2b41b240e3ab47e893ed2c3c4942c459" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_2b41b240e3ab47e893ed2c3c4942c459 = echarts.init(
#             document.getElementById('2b41b240e3ab47e893ed2c3c4942c459'), 'white', {renderer: 'canvas'});
#         var option_2b41b240e3ab47e893ed2c3c4942c459 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 209,
#                 335,
#                 278,
#                 293,
#                 409,
#                 359,
#                 335,
#                 288,
#                 284,
#                 274
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5e73\u5747\u9500\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u529f\u80fd",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u773c\u90e8",
#                 "\u63d0\u62c9",
#                 "\u6b63\u54c1",
#                 "\u4fdd\u6e7f",
#                 "\u8865\u6c34",
#                 "\u773c\u888b",
#                 "\u9ed1\u773c\u5708",
#                 "\u6de1\u5316",
#                 "\u7ec6\u7eb9",
#                 "\u773c\u971c"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e38\u7f8e\u773c\u971c - \u529f\u80fd\u5356\u70b9\u4e0e\u5e73\u5747\u9500\u91cfTOP10"
#         }
#     ]
# };
#         chart_2b41b240e3ab47e893ed2c3c4942c459.setOption(option_2b41b240e3ab47e893ed2c3c4942c459);
#     </script>
# </body>
# </html>

# %%
def filter_keyword_count(df, keyword):
    return int(df[df.raw_title_cut.map(lambda x: keyword in x)].shape[0])

# %%
keywords_mean_count_all = {i[0]:filter_keyword_sales(df,i[0]) for i in reversed(keywords_count_list_all[:10])}
bar = (
    pyecharts.charts.Bar()
    .add_xaxis(list(keywords_mean_count_all.keys()))
    .add_yaxis("", list(keywords_mean_count_all.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position='right'))
    .set_global_opts(
        title_opts = opts.TitleOpts(title="眼霜市场 - 功能与商品数量 TOP10"),
        yaxis_opts = opts.AxisOpts(name='功能'),
        xaxis_opts = opts.AxisOpts(name='商品数量')
    )
)
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="f8be80b720f64499aa7c1667135c43de" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_f8be80b720f64499aa7c1667135c43de = echarts.init(
#             document.getElementById('f8be80b720f64499aa7c1667135c43de'), 'white', {renderer: 'canvas'});
#         var option_f8be80b720f64499aa7c1667135c43de = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 110,
#                 142,
#                 128,
#                 138,
#                 150,
#                 159,
#                 151,
#                 145,
#                 140,
#                 124
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5546\u54c1\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u529f\u80fd",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u773c\u90e8",
#                 "\u63d0\u62c9",
#                 "\u6b63\u54c1",
#                 "\u4fdd\u6e7f",
#                 "\u8865\u6c34",
#                 "\u773c\u888b",
#                 "\u9ed1\u773c\u5708",
#                 "\u6de1\u5316",
#                 "\u7ec6\u7eb9",
#                 "\u773c\u971c"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u773c\u971c\u5e02\u573a - \u529f\u80fd\u4e0e\u5546\u54c1\u6570\u91cf TOP10"
#         }
#     ]
# };
#         chart_f8be80b720f64499aa7c1667135c43de.setOption(option_f8be80b720f64499aa7c1667135c43de);
#     </script>
# </body>
# </html>

# %%
keywords_mean_count_marubi = {i[0]:filter_keyword_sales(df[df.is_marubi_item],i[0]) for i in reversed(keywords_count_list_all[:10])}
bar = (
    pyecharts.charts.Bar()
    .add_xaxis(list(keywords_mean_count_marubi.keys()))
    .add_yaxis("", list(keywords_mean_count_marubi.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position='right'))
    .set_global_opts(
        title_opts = opts.TitleOpts(title="丸美眼霜 - 功能与商品数量 TOP10"),
        yaxis_opts = opts.AxisOpts(name='功能'),
        xaxis_opts = opts.AxisOpts(name='商品数量')
    )
)
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5ba92a4ae8494adc9be75d05be618e11" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_5ba92a4ae8494adc9be75d05be618e11 = echarts.init(
#             document.getElementById('5ba92a4ae8494adc9be75d05be618e11'), 'white', {renderer: 'canvas'});
#         var option_5ba92a4ae8494adc9be75d05be618e11 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 209,
#                 335,
#                 278,
#                 293,
#                 409,
#                 359,
#                 335,
#                 288,
#                 284,
#                 274
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5546\u54c1\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u529f\u80fd",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u773c\u90e8",
#                 "\u63d0\u62c9",
#                 "\u6b63\u54c1",
#                 "\u4fdd\u6e7f",
#                 "\u8865\u6c34",
#                 "\u773c\u888b",
#                 "\u9ed1\u773c\u5708",
#                 "\u6de1\u5316",
#                 "\u7ec6\u7eb9",
#                 "\u773c\u971c"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e38\u7f8e\u773c\u971c - \u529f\u80fd\u4e0e\u5546\u54c1\u6570\u91cf TOP10"
#         }
#     ]
# };
#         chart_5ba92a4ae8494adc9be75d05be618e11.setOption(option_5ba92a4ae8494adc9be75d05be618e11);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### 结论分析二
#
# #### 整体市场
#
# 1. 在整体眼霜行业，商家产品依旧是主打眼霜的基本功能淡化细纹、补水保湿，各类功能卖点在销量上都是差比不大。
# 2. 在销量方面，产品功能的销量大致和商家宣传的热点共相似，__但其中"提拉"眼霜产品数量虽然较少，但销量位居第五名，可能是未来买家的消费新趋势__.
#
# #### 丸美眼霜
#
# 1. 丸美的卖点与整体行业相似，但由于在天猫上销售丸美产品的店铺多达 __126__ 家，销售代理方面有些复杂，导致"官网"、"正品"等成为商家们的宣传口号。
#     - __潜在问题__：过多的专卖店和代理店铺可能导致商品销售商家宣传过于混乱，各自标榜正品,导致买家在品牌认知上难以一致，对旗舰店会造成品牌认知干扰。
# 2. 丸美眼霜的商品数量和销量大致呈线性关系，产品功能开发商与市场需求比较符合。
# 3. 含"正品"关键字的产品数量高达176个的原因：
#     - 主要是专卖店的商品宣传中都会含"正品"关键字,其中天猫上所有专卖店标有"正品"的商品合计为126个。

# %%
def filter_price(df_series,num):
#     step 1:
#         按照：MAX = Q3+(Q3-Q1)*1.5
#               MIX = Q1-(Q3-Q1)*1.5
#         剔除异常值，在分区
#     step 2:
#         对区间的值进行修正
    qmin_ = df_series.quantile(0.25) - (df_series.quantile(0.75)-df_series.quantile(0.25))*1.5
    qmax_ = df_series.quantile(0.75) + (df_series.quantile(0.75)-df_series.quantile(0.25))*1.5
    tmin = df_series.min()
    tmax = df_series.max()
    def filter_(x, min_, max_):
        if x<min_: return min_
        if x>max_: return max_
        return x
    return pd.cut(df_series.map(lambda x: filter_(x,qmin_, qmax_)),num)

def fix_cut(x, min_, max_):
    price, price_cut = x[0], x[1]
    if price<price_cut.left:
        return pd.Interval(min_, price_cut.right)
    elif price>price_cut.right:
        return pd.Interval(price_cut.left, max_)
    else:
        return price_cut

# %%
df['price_cuts'] = filter_price(df.view_price, 10)
df['price_cuts'] = df[['view_price', 'price_cuts']].apply(lambda x: fix_cut(x,df.view_price.min(), df.view_price.max()),axis=1)

# %%
data = df.price_cuts.value_counts().reset_index(name='count').sort_values('index')
data['index'] = data['index'].map(str)
bar4 = (
    pyecharts.charts.Bar()
    .add_xaxis(data['index'].tolist())
    .add_yaxis('', data['count'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='眼霜市场 - 商品价格区间分布柱状图'))
)
bar4.load_javascript()

# %%
bar4.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="69115d7e96d64cafb32d404e29333417" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_69115d7e96d64cafb32d404e29333417 = echarts.init(
#             document.getElementById('69115d7e96d64cafb32d404e29333417'), 'white', {renderer: 'canvas'});
#         var option_69115d7e96d64cafb32d404e29333417 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 211,
#                 1105,
#                 794,
#                 681,
#                 389,
#                 311,
#                 184,
#                 155,
#                 63,
#                 72,
#                 314
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "(8.411, 57.81]",
#                 "(57.81, 106.72]",
#                 "(106.72, 155.63]",
#                 "(155.63, 204.54]",
#                 "(204.54, 253.45]",
#                 "(253.45, 302.36]",
#                 "(302.36, 351.27]",
#                 "(351.27, 400.18]",
#                 "(400.18, 449.09]",
#                 "(449.09, 498.0]",
#                 "(449.09, 4089.0]"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u773c\u971c\u5e02\u573a - \u5546\u54c1\u4ef7\u683c\u533a\u95f4\u5206\u5e03\u67f1\u72b6\u56fe"
#         }
#     ]
# };
#         chart_69115d7e96d64cafb32d404e29333417.setOption(option_69115d7e96d64cafb32d404e29333417);
#     </script>
# </body>
# </html>

# %%
data = df.price_cuts.value_counts().reset_index(name='count').sort_values('index')
data['index'] = data['index'].map(str)
pie = (
    pyecharts.charts.Pie()
    .add("", data.values.tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title=''))
    .set_series_opts(title_opts=opts.LabelOpts(formatter="{b}:{c}"))
)
pie.load_javascript()

# %%
print("眼霜市场 - 商品价格区间分布饼图\n")
pie.render_notebook()
# Out:
# 眼霜市场 - 商品价格区间分布饼图
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="eaa448df34bc41a5b307b0357f3464e9" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_eaa448df34bc41a5b307b0357f3464e9 = echarts.init(
#             document.getElementById('eaa448df34bc41a5b307b0357f3464e9'), 'white', {renderer: 'canvas'});
#         var option_eaa448df34bc41a5b307b0357f3464e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "(8.411, 57.81]",
#                     "value": 211
#                 },
#                 {
#                     "name": "(57.81, 106.72]",
#                     "value": 1105
#                 },
#                 {
#                     "name": "(106.72, 155.63]",
#                     "value": 794
#                 },
#                 {
#                     "name": "(155.63, 204.54]",
#                     "value": 681
#                 },
#                 {
#                     "name": "(204.54, 253.45]",
#                     "value": 389
#                 },
#                 {
#                     "name": "(253.45, 302.36]",
#                     "value": 311
#                 },
#                 {
#                     "name": "(302.36, 351.27]",
#                     "value": 184
#                 },
#                 {
#                     "name": "(351.27, 400.18]",
#                     "value": 155
#                 },
#                 {
#                     "name": "(400.18, 449.09]",
#                     "value": 63
#                 },
#                 {
#                     "name": "(449.09, 498.0]",
#                     "value": 72
#                 },
#                 {
#                     "name": "(449.09, 4089.0]",
#                     "value": 314
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "title_opts": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:{c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "(8.411, 57.81]",
#                 "(57.81, 106.72]",
#                 "(106.72, 155.63]",
#                 "(155.63, 204.54]",
#                 "(204.54, 253.45]",
#                 "(253.45, 302.36]",
#                 "(302.36, 351.27]",
#                 "(351.27, 400.18]",
#                 "(400.18, 449.09]",
#                 "(449.09, 498.0]",
#                 "(449.09, 4089.0]"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {}
#     ]
# };
#         chart_eaa448df34bc41a5b307b0357f3464e9.setOption(option_eaa448df34bc41a5b307b0357f3464e9);
#     </script>
# </body>
# </html>

# %% [markdown]
# ## 结论分析三
#
# 1. 眼霜整体市场的价格分布主要集中在57-204左右，大约占比58%
